# %% [markdown]
# OpenAI Whisper - https://github.com/openai/whisper

# %% [markdown]
# # GPU Check

# %%
# !nvidia-smi
# Out:
# Sun Sep 25 19:00:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Installation

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#      |████████████████████████████████| 4.9 MB 29.4 MB/s
#      |████████████████████████████████| 6.6 MB 58.1 MB/s
#      |████████████████████████████████| 120 kB 71.6 MB/s
#   Building wheel for whisper (setup.py) ... done

# %% [markdown]
# # Load the Library * Model

# %%
import whisper

model = whisper.load_model("medium") #769M Parameter
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:22<00:00, 68.3MiB/s]

# %%
# !wget -O audio.mp3 http://www.moviesoundclips.net/movies1/batmanbegins/bats.mp3
# Out:
# --2022-09-25 19:19:53--  http://www.moviesoundclips.net/movies1/batmanbegins/bats.mp3
# Resolving www.moviesoundclips.net (www.moviesoundclips.net)... 198.54.115.219
# Connecting to www.moviesoundclips.net (www.moviesoundclips.net)|198.54.115.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52128 (51K) [audio/mpeg]
# Saving to: ‘audio.mp3’
#
# audio.mp3           100%[===================>]  50.91K  87.9KB/s    in 0.6s
#
# 2022-09-25 19:19:54 (87.9 KB/s) - ‘audio.mp3’ saved [52128/52128]

# %%
from IPython.display import Audio, display

display(Audio('audio.mp3', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Speech to Text Transcription

# %%
result = model.transcribe("audio.mp3")
print(result["text"])
# Out:
# Detected language: english
#  Bats are not pernil. Bats may be, but even a billionaire playboy's, three o'clock is pushing him.

# %%
import whisper

tiny = whisper.load_model("tiny")
# Out:
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:01<00:00, 63.7MiB/s]

# %%
result = tiny.transcribe("audio.mp3")
print(result["text"])
# Out:
# Detected language: english
#  That's your knock journal. That's my bait. But even a billionaire playboy. Where the clock is pushing me...

# %% [markdown]
# # 3 lines of Python Code for Speech-to-Text

# %%
import whisper
model = whisper.load_model('medium')
model.transcribe("audio.mp3")['text']
# Out:
# Detected language: english
# " Bats are not pernil. Bats may be, but even a billionaire playboy's, three o'clock is pushing him."
